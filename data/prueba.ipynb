# %% [markdown]
# <a href="https://colab.research.google.com/github/datacryptoc/Extraccion-Caracteristicas-Imagen/blob/main/data/prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#prueba

# %% [markdown]
# # Nueva sección
