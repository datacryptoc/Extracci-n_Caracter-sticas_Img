# %%
#!git clone https://github.com/datacryptoc/Extraccion-Caracteristicas-Imagen.git
# %cd Extraccion-Caracteristicas-Imagen/
# Out:
# /content/Extraccion-Caracteristicas-Imagen

# %%
# %cd ..
# Out:
# /content

# %%
os.chdir(dir)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-77714a921615> in <module>
# ----> 1 os.chdir(dir)
#
# TypeError: chdir: path should be string, bytes, os.PathLike or integer, not SList

# %%
import os
import numpy as np
import keras.utils as image
import matplotlib.pyplot as plt
import cv2
from scipy.interpolate import interp2d

# %%
#!pip install opencv-python
path_img = './data/ciudad.jpg'
# Cargar la imagen de prueba
img = image.load_img(path_img, target_size=(224, 224))

plt.imshow(img)
